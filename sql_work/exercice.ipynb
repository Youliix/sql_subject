# %% [markdown]
# ## 1. Récupération de la DB et schéma de base de donnée

# %% [markdown]
# Récupérer la base de données `blog.sqlite`

# %%
import sqlite3

# %%
conn = sqlite3.connect('./blog.sqlite')
cur = conn.cursor()

# %% [markdown]
# ![Texte alternatif](bdd.png)

# %% [markdown]
# Réaliser un schéma de base de donnée (diagramme entité-relation (ERD)) à l'aide d'un outil, par exemple <a href='https://www.dbdesigner.net/' target="_blank">DB designer </a>

# %% [markdown]
# ---
# ## 2. Retourner le top 3 des articles les plus liké.

# %%
query = """
        SELECT posts.title 
        FROM posts 
        JOIN likes ON posts.id = likes.post_id 
        GROUP BY posts.title 
        ORDER BY COUNT(likes.post_id) DESC
        LIMIT 3;
        """
print(cur.execute(query).fetchall())
# Out:
# [('Half imagine another.',), ('Side foot leader popular.',), ('Area paper whatever mean.',)]

# %% [markdown]
# ---
# ## 3. Trouvez les trois utilisateurs qui ont le plus liké

# %%
query = """
        SELECT users.first_name || ' ' || users.last_name AS name 
        FROM users 
        JOIN likes ON users.id = likes.user_id 
        GROUP BY users.id 
        ORDER BY COUNT(likes.user_id) DESC 
        LIMIT 3;
        """
print(cur.execute(query).fetchall())
# Out:
# [('Michael Allen',), ('Donna Ramirez',), ('Hayley Williams',)]

# %% [markdown]
# ---
# ## 4. Trouver l'auteur le plus apprécié

# %%
query = """
        SELECT users.first_name || ' ' || users.last_name AS name 
        FROM users 
        JOIN likes ON users.id = likes.user_id 
        GROUP BY likes.post_id
        ORDER BY COUNT(likes.user_id) DESC;
        """
print(cur.execute(query).fetchone())
# Out:
# ('Bradley Kelly',)

# %% [markdown]
# ---
# ## 5. Qui sont les auteurs des 3 articles les plus likés ?

# %%
query = """
        SELECT users.first_name || ' ' || users.last_name AS name 
        FROM users 
        JOIN likes ON users.id = likes.user_id 
        GROUP BY likes.post_id 
        ORDER BY COUNT(likes.user_id) DESC 
        LIMIT 3;
        """
print(cur.execute(query).fetchall())
# Out:
# [('Bradley Kelly',), ('Daniel Booth',), ('Cory Bush',)]

# %% [markdown]
# ---
# ## 6. Combien de personnes ont aimé au moins une publication ?

# %%
query = """
        SELECT SUM(subquery.user_count) as users_count 
        FROM (
            SELECT COUNT(DISTINCT user_id) as user_count FROM likes
            ) 
        AS subquery;"""
print(cur.execute(query).fetchone())
# Out:
# (49,)

# %% [markdown]
# ---
# ## 7. Calculez le nombre cumulé de likes par jour

# %%
query = """
        SELECT l1.created_at,
        (SELECT SUM(l2.id) FROM likes AS l2 WHERE l2.created_at <= l1.created_at AND l2.created_at = l1.created_at) AS cumul_likes
        FROM likes as l1
        GROUP BY l1.created_at
        ORDER BY l1.created_at ASC;
        """
print(cur.execute(query).fetchall())
# Out:
# [('2019-01-01', 124124), ('2019-01-02', 175187), ('2019-01-03', 221761), ('2019-01-04', 193885), ('2019-01-05', 136956), ('2019-01-06', 79699), ('2019-01-07', 135173), ('2019-01-08', 135540), ('2019-01-09', 195793), ('2019-01-10', 135089), ('2019-01-11', 128399), ('2019-01-12', 150020), ('2019-01-13', 184713), ('2019-01-14', 117433), ('2019-01-15', 138465), ('2019-01-16', 171619), ('2019-01-17', 184516), ('2019-01-18', 95175), ('2019-01-19', 99352), ('2019-01-20', 134700), ('2019-01-21', 127762), ('2019-01-22', 118977), ('2019-01-23', 168496), ('2019-01-24', 127696), ('2019-01-25', 147046), ('2019-01-26', 190169), ('2019-01-27', 170136), ('2019-01-28', 144503), ('2019-02-01', 104743), ('2019-02-02', 117425), ('2019-02-03', 174830), ('2019-02-04', 158164), ('2019-02-05', 149098), ('2019-02-06', 148829), ('2019-02-07', 119447), ('2019-02-08', 153564), ('2019-02-09', 115352), ('2019-02-10', 135232), ('2019-02-11', 171066), ('2019-02-12', 102727), ('2019-02-13', 143839), ('2019-02-14', 176824), ('2019-02-15', 103594), ('2019-02-16', 117760), ('2019-02-17', 218481), ('2019-02-18', 122364), ('2019-02-19', 176620), ('2019-02-20', 134481), ('2019-02-21', 105218), ('2019-02-22', 189080), ('2019-02-23', 133020), ('2019-02-24', 157619), ('2019-02-25', 171604), ('2019-02-26', 134391), ('2019-02-27', 162176), ('2019-02-28', 147421), ('2019-03-01', 138071), ('2019-03-02', 210451), ('2019-03-03', 151725), ('2019-03-04', 163376), ('2019-03-05', 153952), ('2019-03-06', 97304), ('2019-03-07', 109019), ('2019-03-08', 129934), ('2019-03-09', 205989), ('2019-03-10', 128151), ('2019-03-11', 209119), ('2019-03-12', 155057), ('2019-03-13', 126178), ('2019-03-14', 115525), ('2019-03-15', 146773), ('2019-03-16', 134340), ('2019-03-17', 179277), ('2019-03-18', 173822), ('2019-03-19', 110424), ('2019-03-20', 120279), ('2019-03-21', 110114), ('2019-03-22', 132630), ('2019-03-23', 138386), ('2019-03-24', 147974), ('2019-03-25', 110029), ('2019-03-26', 177600), ('2019-03-27', 171181), ('2019-03-28', 195958), ('2019-04-01', 164879), ('2019-04-02', 150961), ('2019-04-03', 128880), ('2019-04-04', 152968), ('2019-04-05', 166557), ('2019-04-06', 171943), ('2019-04-07', 113468), ('2019-04-08', 163812), ('2019-04-09', 114356), ('2019-04-10', 144387), ('2019-04-11', 143644), ('2019-04-12', 150728), ('2019-04-13', 128623), ('2019-04-14', 123577), ('2019-04-15', 139072), ('2019-04-16', 148108), ('2019-04-17', 90487), ('2019-04-18', 156828), ('2019-04-19', 106064), ('2019-04-20', 184527), ('2019-04-21', 183850), ('2019-04-22', 152603), ('2019-04-23', 143808), ('2019-04-24', 150163), ('2019-04-25', 139529), ('2019-04-26', 153139), ('2019-04-27', 144327), ('2019-04-28', 161454), ('2019-05-01', 169049), ('2019-05-02', 151501), ('2019-05-03', 122437), ('2019-05-04', 135225), ('2019-05-05', 154572), ('2019-05-06', 174276), ('2019-05-07', 169126), ('2019-05-08', 167658), ('2019-05-09', 141141), ('2019-05-10', 172431), ('2019-05-11', 164947), ('2019-05-12', 102763), ('2019-05-13', 142055), ('2019-05-14', 97176), ('2019-05-15', 225228), ('2019-05-16', 90721), ('2019-05-17', 188137), ('2019-05-18', 214204), ('2019-05-19', 115511), ('2019-05-20', 156229), ('2019-05-21', 176471), ('2019-05-22', 132682), ('2019-05-23', 120773), ('2019-05-24', 163457), ('2019-05-25', 181928), ('2019-05-26', 151074), ('2019-05-27', 90511), ('2019-05-28', 185196), ('2019-06-01', 149808), ('2019-06-02', 87492), ('2019-06-03', 166153), ('2019-06-04', 161017), ('2019-06-05', 154085), ('2019-06-06', 142405), ('2019-06-07', 165434), ('2019-06-08', 132545), ('2019-06-09', 202945), ('2019-06-10', 146273), ('2019-06-11', 108651), ('2019-06-12', 92934), ('2019-06-13', 121462), ('2019-06-14', 152906), ('2019-06-15', 154113), ('2019-06-16', 103203), ('2019-06-17', 132823), ('2019-06-18', 129994), ('2019-06-19', 174821), ('2019-06-20', 187721), ('2019-06-21', 152819), ('2019-06-22', 179272), ('2019-06-23', 116381), ('2019-06-24', 93971), ('2019-06-25', 161965), ('2019-06-26', 206587), ('2019-06-27', 216414), (' ...

# %% [markdown]
# ---
# ## 8. (Optional) Qui est le(s) plus grand(s) fan(s) de chaque auteur ?
#
# <p>
# Le ou les plus grands fans d'un auteur sont définis comme le ou les utilisateurs qui ont le plus aimé les publications de l'auteur. c'est-à-dire que s'il y a égalité entre les fans qui ont tous deux aimé un auteur 20 fois, les deux fans doivent être renvoyés avec leur nombre de likes et l'auteur en question.</p>
#
# <p>Indice : Vous pouvez utiliser <code>WITH</code></p>

# %%
# TOP1 ou TOP2 users for n post from 1 user_id for each user from posts table
query = """
WITH Classement AS (
    SELECT
        posts.user_id as author_id,
        likes.user_id,
        posts.id as post_id,
        SUM(likes.id) AS nb_likes,
        RANK() OVER (PARTITION BY posts.id, posts.user_id ORDER BY SUM(likes.id) DESC) as classement
    FROM
        likes 
    JOIN
        posts ON posts.id = likes.post_id
    GROUP BY 
        posts.user_id, likes.user_id, posts.id
)
SELECT
    author_id,
    post_id,
    nb_likes,
    user_id
FROM
    Classement
WHERE
    classement = 1;
"""
print(cur.execute(query).fetchall())
# Out:
# [(50, 1, 21973, 16), (50, 2, 16627, 9), (50, 3, 22817, 4), (50, 4, 25532, 33), (50, 5, 25912, 39), (51, 6, 22533, 24), (51, 7, 23951, 12), (51, 8, 23972, 46), (51, 9, 39491, 11), (51, 10, 22436, 11), (51, 11, 20358, 6), (51, 12, 25413, 21), (51, 13, 27676, 8), (51, 14, 27139, 34), (51, 15, 31206, 46), (52, 16, 28194, 3), (52, 17, 27653, 2), (52, 18, 24521, 44), (52, 19, 23813, 32), (52, 20, 24720, 31), (52, 21, 24080, 24), (52, 22, 19761, 21), (52, 23, 28453, 48), (53, 24, 24025, 34), (54, 25, 26332, 36), (54, 26, 28463, 44), (54, 27, 22450, 18), (55, 28, 23033, 27), (55, 29, 15618, 31), (55, 30, 29086, 29), (55, 31, 17331, 9), (55, 32, 20354, 33), (55, 33, 18833, 14), (55, 34, 29193, 18), (55, 35, 25989, 25), (56, 36, 24836, 38), (56, 37, 34182, 31), (56, 38, 26065, 29), (56, 39, 30711, 12), (57, 40, 23005, 42), (57, 41, 21552, 2), (57, 42, 32661, 2), (57, 43, 25914, 45), (57, 44, 45348, 27), (57, 45, 25823, 1), (57, 46, 26817, 39), (57, 47, 30484, 9), (57, 48, 25786, 49), (57, 49, 25534, 9), (58, 50, 29862, 46), (58, 51, 20666, 29), (58, 52, 16187, 41), (58, 53, 33854, 5), (58, 54, 28643, 8), (58, 55, 31196, 17), (58, 56, 29008, 37), (58, 57, 25272, 9), (59, 58, 31617, 48), (59, 59, 21490, 49), (60, 60, 33353, 35), (60, 61, 28650, 4), (60, 62, 24905, 3), (60, 63, 24466, 20), (60, 64, 16826, 45), (60, 65, 28860, 33), (60, 66, 23338, 20), (61, 67, 25004, 22), (61, 68, 26601, 49), (61, 69, 18928, 38), (61, 70, 25313, 38), (61, 71, 26455, 36), (61, 72, 33225, 15), (61, 73, 25542, 48), (61, 74, 35386, 4), (62, 75, 24338, 46), (62, 76, 19088, 49), (62, 77, 26730, 49), (62, 78, 30353, 12), (62, 79, 21204, 44), (62, 80, 24445, 20), (62, 81, 23815, 39), (63, 82, 23876, 42), (63, 83, 38511, 14), (63, 84, 26366, 16), (63, 85, 31983, 42), (63, 86, 25876, 10), (63, 87, 16612, 40), (63, 88, 36504, 17), (63, 89, 23683, 41), (63, 90, 29579, 6), (64, 91, 20910, 47), (64, 92, 23948, 24), (64, 93, 15335, 12), (64, 94, 23676, 9), (64, 95, 24698, 35), (64, 96, 27228, 47), (64, 97, 21941, 16), (64, 98, 25944, 44), (64, 99, 37618, 4), (65, 100, 26815, 45), (65, 101, 19091, 16), (66, 102, 27855, 18), (66, 103, 21952, 47), (67, 104, 23365, 38), (67, 105, 27596, 29), (67, 106, 20967, 16), (67, 107, 22332, 5), (67, 108, 27508, 30), (67, 109, 23251, 37), (67, 110, 33859, 5), (67, 111, 27589, 24), (67, 112, 17907, 18), (67, 113, 27973, 21), (68, 114, 21225, 46), (68, 115, 31349, 35), (68, 116, 25837, 20), (68, 117, 21872, 46), (68, 118, 25401, 44), (68, 119, 23983, 30), (69, 120, 15956, 12), (69, 121, 24227, 37), (69, 122, 29372, 36), (69, 123, 26476, 34), (69, 124, 27282, 29), (69, 125, 31662, 28), (69, 126, 23878, 42), (69, 127, 29751, 10), (69, 128, 26119, 37), (69, 129, 28751, 29), (70, 130, 23330, 19), (70, 131, 24081, 8), (70, 132, 23845, 30), (70, 133, 22165, 46), (70, 134, 21107, 27), (70, 135, 32693, 37), (70, 136, 23121, 22), (70, 137, 25112, 47), (71, 138, 22648, 7), (71, 139, 23229, 22), (71, 140, 27668, 30), (71, 141, 24773, 5), (71, 142, 32684, 17), (72, 143, 30442, 45), (73, 144, 27878, 32), (73, 145, 25122, 31), (73, 146, 18213, 16), (73, 147, 23024, 34), (73, 148, 23873, 8), (74, 149, 21397, 25), (74, 150, 29889, 25), (74, 151, 28012, 10), (74, 152, 19610, 44), (74, 153, 24366, 19), (74, 154, 25934, 44), (74, 155, 24953, 44), (74, 156, 32020, 33), (74, 157, 27381, 42), (74, 158, 22546, 15)]
